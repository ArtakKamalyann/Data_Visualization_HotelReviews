# %% [markdown]
# ## Importing Packages and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import seaborn as sns
from datetime import datetime
import folium

# %%
data=pd.read_csv(r'Hotel_Reviews.csv')

# %% [markdown]
# ## Preliminary Analysis of data

# %%
data.isna().sum()
# Out:
# Hotel_Address                                    0
# Additional_Number_of_Scoring                     0
# Review_Date                                      0
# Average_Score                                    0
# Hotel_Name                                       0
# Reviewer_Nationality                             0
# Negative_Review                                  0
# Review_Total_Negative_Word_Counts                0
# Total_Number_of_Reviews                          0
# Positive_Review                                  0
# Review_Total_Positive_Word_Counts                0
# Total_Number_of_Reviews_Reviewer_Has_Given       0
# Reviewer_Score                                   0
# Tags                                             0
# days_since_review                                0
# lat                                           3268
# lng                                           3268
# dtype: int64

# %%
data.dtypes
# Out:
# Hotel_Address                                  object
# Additional_Number_of_Scoring                    int64
# Review_Date                                    object
# Average_Score                                 float64
# Hotel_Name                                     object
# Reviewer_Nationality                           object
# Negative_Review                                object
# Review_Total_Negative_Word_Counts               int64
# Total_Number_of_Reviews                         int64
# Positive_Review                                object
# Review_Total_Positive_Word_Counts               int64
# Total_Number_of_Reviews_Reviewer_Has_Given      int64
# Reviewer_Score                                float64
# Tags                                           object
# days_since_review                              object
# lat                                           float64
# lng                                           float64
# dtype: object

# %%
print('There are' + ' ' + str(data.shape[0])+' '+ 'rows')
print('There are' + ' ' + str(data.shape[1])+' '+ 'columns')
# Out:
# There are 515738 rows
# There are 19 columns

# %%
cat_cols=[]
num_cols = []
for col in data.columns:
    if data[col].dtype == object:
        cat_cols.append(col)
    else:
        num_cols.append(col)
        
num_cols=['Additional_Number_of_Scoring',
 'Average_Score',
 'Review_Total_Negative_Word_Counts',
 'Total_Number_of_Reviews',
 'Review_Total_Positive_Word_Counts',
 'Total_Number_of_Reviews_Reviewer_Has_Given']

# %%
#Printing out Hotels having very high average score
data[data.Average_Score >= 9][['Hotel_Name','Average_Score','Total_Number_of_Reviews']].drop_duplicates().sort_values(by ='Total_Number_of_Reviews',ascending = False)[:20]
# Out:
#                                        Hotel_Name  Average_Score  \
# 57597   M by Montcalm Shoreditch London Tech City            9.1
# 450210                             Hotel Esther a            9.1
# 180550                   citizenM Tower of London            9.1
# 14829              Intercontinental London The O2            9.4
# 470003                    The Square Milano Duomo            9.0
# 483570                                Hotel Berna            9.2
# 464405                             Hotel Stefanie            9.1
# 96177                    citizenM London Bankside            9.1
# 100530                            Mondrian London            9.1
# 418909                         art otel Amsterdam            9.0
# 454064                 Hilton London Canary Wharf            9.0
# 342079              Steigenberger Hotel Herrenhof            9.0
# 494173                  Bianca Maria Palace Hotel            9.0
# 414395                         Olivia Plaza Hotel            9.3
# 387956                  Apex City Of London Hotel            9.0
# 971                       Apex Temple Court Hotel            9.2
# 85479                      Hilton London Bankside            9.3
# 396186                          Hotel Am Parkring            9.0
# 228012             The Piccadilly London West End            9.0
# 448911                           Hotel Capricorno            9.1
#
#         Total_Number_of_Reviews
# 57597                      4802
# 450210                     4687
# 180550                     4672
# 14829                      4204
# 470003                     4192
# 483570                     4017
# 464405                     3883
# 96177                      3802
# 100530                     3611
# 418909                     3158
# 454064                     3040
# 342079                     2873
# 494173                     2770
# 414395                     2757
# 387956                     2750
# 971                        2619
# 85479                      2319
# 396186                     2304
# 228012                     2298
# 448911                     2279

# %%
#Reviewer score has values not exceeding 10 and majority in out data have high score
data['Reviewer_Score'].value_counts().head(20).plot.bar(color='g')
# Out:
# <AxesSubplot:>

# %%
#Analysis of best and worst hotels in terms of average score

# %%
grouped_hotel_score=data.groupby(['Hotel_Name'])['Average_Score'].mean().reset_index().sort_values(by=['Average_Score']).head(5)
top5_hotels=grouped_hotel_score[['Hotel_Name']]                                                                                                                          
plt.bar(grouped_hotel_score['Hotel_Name'], grouped_hotel_score['Average_Score'])
plt.xticks(rotation=60)
plt.xlabel('Hotel_Name')
plt.ylabel('Average_Score')
plt.show()

# %%
top5_hotels
# Out:
#                                     Hotel_Name
# 678                              Hotel Liberty
# 600                            Hotel Cavendish
# 1233                     Savoy Hotel Amsterdam
# 141   Best Western Maitrise Hotel Edgware Road
# 1401                         The Tophams Hotel

# %%
top5_df=data[data['Hotel_Name'].isin(top5_hotels['Hotel_Name'].tolist())]

# %%
top5_df
# Out:
#                                             Hotel_Address  \
# 129781  28 Ebury Street Westminster Borough London SW1...
# 129782  28 Ebury Street Westminster Borough London SW1...
# 129783  28 Ebury Street Westminster Borough London SW1...
# 129784  28 Ebury Street Westminster Borough London SW1...
# 129785  28 Ebury Street Westminster Borough London SW1...
# ...                                                   ...
# 494851  Viale Bligny 56 Milan City Center 20136 Milan ...
# 494852  Viale Bligny 56 Milan City Center 20136 Milan ...
# 494853  Viale Bligny 56 Milan City Center 20136 Milan ...
# 494854  Viale Bligny 56 Milan City Center 20136 Milan ...
# 494855  Viale Bligny 56 Milan City Center 20136 Milan ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 129781                            60   7/20/2017            6.6
# 129782                            60   7/16/2017            6.6
# 129783                            60   7/12/2017            6.6
# 129784                            60    7/9/2017            6.6
# 129785                            60   6/27/2017            6.6
# ...                              ...         ...            ...
# 494851                            26   10/5/2015            5.2
# 494852                            26   10/1/2015            5.2
# 494853                            26   9/24/2015            5.2
# 494854                            26   9/10/2015            5.2
# 494855                            26   9/10/2015            5.2
#
#                Hotel_Name    Reviewer_Nationality  \
# 129781  The Tophams Hotel         United Kingdom
# 129782  The Tophams Hotel         United Kingdom
# 129783  The Tophams Hotel            Netherlands
# 129784  The Tophams Hotel            Philippines
# 129785  The Tophams Hotel                 Canada
# ...                   ...                     ...
# 494851      Hotel Liberty           South Africa
# 494852      Hotel Liberty              Australia
# 494853      Hotel Liberty                 France
# 494854      Hotel Liberty   United Arab Emirates
# 494855      Hotel Liberty                  Italy
#
#                                           Negative_Review  \
# 129781   Room was covered in damp missing wallpaper li...
# 129782   On arrival my friend and I thought that the l...
# 129783   I booked two rooms with twin beds On arrival ...
# 129784   The elevator is broken and the room is soooo ...
# 129785   air con faulty no shower door water all over ...
# ...                                                   ...
# 494851   It feels like a 2 star hotel masquerading as ...
# 494852   Air con was ineffective so it was pretty warm...
# 494853                     pas de chaines internationales
# 494854                                        Ac not good
# 494855                          Not very clean for 4 star
#
#         Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 129781                                 40                      411
# 129782                                 99                      411
# 129783                                 74                      411
# 129784                                 19                      411
# 129785                                 29                      411
# ...                                   ...                      ...
# 494851                                 14                      465
# 494852                                 19                      465
# 494853                                  5                      465
# 494854                                  4                      465
# 494855                                  7                      465
#
#                                           Positive_Review  \
# 129781                                           Location
# 129782   The reception area and dining room were very ...
# 129783               Located quite near Victoria station
# 129784   The location is very good and there are plent...
# 129785                                           location
# ...                                                   ...
# 494851                                        No Positive
# 494852    Quiet area good breakfast and nice clean hotel
# 494853                                        No Positive
# 494854                                   V friendly staff
# 494855   Friendly and available staff Location is very...
#
#         Review_Total_Positive_Word_Counts  \
# 129781                                  2
# 129782                                 11
# 129783                                  7
# 129784                                 16
# 129785                                  2
# ...                                   ...
# 494851                                  0
# 494852                                 10
# 494853                                  0
# 494854                                  4
# 494855                                 13
#
#         Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 129781                                           2             3.8
# 129782                                           5             6.3
# 129783                                          16             5.0
# 129784                                           2             6.7
# 129785                                           7             7.9
# ...                                            ...             ...
# 494851                                           6             3.8
# 494852                                          16             7.5
# 494853                                           2             7.1
# 494854                                           9             6.3
# 494855                                           7             7.5
#
#                                                      Tags days_since_review  \
# 129781  [' Leisure trip ', ' Couple ', ' Double Room '...           14 days
# 129782  [' Leisure trip ', ' Group ', ' Twin Room ', '...           18 days
# 129783  [' Leisure trip ', ' Family with young childre...           22 days
# 129784  [' Leisure trip ', ' Family with young childre...           25 days
# 129785  [' Leisure trip ', ' Couple ', ' Lower Ground ...           37 days
# ...                                                   ...               ...
# 494851  [' Leisure trip ', ' Couple ', ' Double Room '...           668 day
# 494852  [' Leisure trip ', ' Solo traveler ', ' Double...           672 day
# 494853  [' Leisure trip ', ' Couple ', ' Double Room '...           679 day
# 494854  [' Leisure trip ', ' Group ', ' Double Room ',...           693 day
# 494855  [' Leisure trip ', ' Couple ', ' Double Room '...           693 day
#
#               lat       lng
# 129781  51.495744 -0.147753
# 129782  51.495744 -0.147753
# 129783  51.495744 -0.147753
# 129784  51.495744 -0.147753
# 129785  51.495744 -0.147753
# ...           ...       ...
# 494851  45.450867  9.194866
# 494852  45.450867  9.194866
# 494853  45.450867  9.194866
# 494854  45.450867  9.194866
# 494855  45.450867  9.194866
#
# [1628 rows x 17 columns]

# %%
text = top5_df['Positive_Review'].str.lower().str.replace('[^a-zA-Z\s]+', '')
words = text.str.split()
filtered_words = words.apply(lambda x: [word for word in x if word not in STOPWORDS])
word_freq = pd.Series(filtered_words.sum()).value_counts()
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# /var/folders/gx/v6_w9frd0jjc05rh4hzqcpdc0000gn/T/ipykernel_2889/3738626112.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = top5_df['Positive_Review'].str.lower().str.replace('[^a-zA-Z\s]+', '')

# %%
grouped_hotel_score=data.groupby(['Hotel_Name'])['Average_Score'].mean().reset_index().sort_values(by=['Average_Score']).tail(5)
lowest5_hotels=grouped_hotel_score[['Hotel_Name']]                                                                                                                          
plt.bar(grouped_hotel_score['Hotel_Name'], grouped_hotel_score['Average_Score'])
plt.xticks(rotation=60)
plt.xlabel('Hotel_Name')
plt.ylabel('Average_Score')
plt.show()

# %%
lowest5_hotels_df=data[data['Hotel_Name'].isin(lowest5_hotels['Hotel_Name'].tolist())]

# %%
text = lowest5_hotels_df['Negative_Review'].str.lower().str.replace('[^a-zA-Z\s]+', '')
words = text.str.split()
filtered_words = words.apply(lambda x: [word for word in x if word not in STOPWORDS])
word_freq = pd.Series(filtered_words.sum()).value_counts()
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# /var/folders/gx/v6_w9frd0jjc05rh4hzqcpdc0000gn/T/ipykernel_2889/4186283726.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   text = lowest5_hotels_df['Negative_Review'].str.lower().str.replace('[^a-zA-Z\s]+', '')

# %%
#Analysing the nationality of reviewers
#Taking top 10 countries in terms of number of reviewers so that we have significant number of observations 
#for calculating mean
top10=data['Reviewer_Nationality'].value_counts().head(10).index.tolist()
data_top10=data[data['Reviewer_Nationality'].isin(top10)]
data_2 = data_top10.groupby(['Reviewer_Nationality'], as_index=False).mean('Average_Score')
data_2.sort_values('Average_Score',ascending=False)
xAx=data_2.sort_values('Average_Score',ascending=True)['Reviewer_Nationality'].head(10)
yAx=data_2.sort_values('Average_Score',ascending=True)['Average_Score'].head(10)
plt.figure(figsize=(17,8))
plt.bar(xAx,yAx,color='y')
plt.xticks(rotation = 45)
x=0.0
for xItem, yItem in zip(xAx,yAx):
    
    plt.text(x-0.2,yItem+0.22, '({})'.format(round(yItem,2)),fontsize=12,
             verticalalignment='center')
    x=x+1

# %%
#Boxplots to see some outliers
data[['Additional_Number_of_Scoring','Average_Score',
    'Total_Number_of_Reviews_Reviewer_Has_Given','Reviewer_Score','Total_Number_of_Reviews','Review_Total_Negative_Word_Counts','Review_Total_Positive_Word_Counts']].plot(kind = "box" , subplots = True , figsize = (24,20) ,  layout = (4,4))
plt.show()

# %%
#Correlation heatmap of the variables, there is high correlation between additional number of scoring and total number of reviews
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),cmap = 'coolwarm',linewidth = 1,annot= True, annot_kws={"size": 9})
# Out:
# <AxesSubplot:>

# %%
data['hotel_city']=data['Hotel_Address'].apply(lambda x: x.split()[-2])
data['hotel_country']=data['Hotel_Address'].apply(lambda x: x.split()[-1])

# %%
data['hotel_country'].isna().sum()
# Out:
# 0

# %%
#No significant difference between countries
grouped=data.groupby(['hotel_country'])['Average_Score'].mean().reset_index()                                                                                                                      
plt.bar(grouped['hotel_country'],grouped['Average_Score'],color='y')
plt.xticks(rotation=60)
plt.xlabel('Hotel_country')
plt.ylabel('Average_Score')
plt.show()

# %%
for col in num_cols:
    sns.displot(data[col], kde=True)
    plt.show()
